# %%
#writing a basic Bokeh line graph

#importing Bokeh
from bokeh.plotting import figure
from bokeh.io import output_file, show

#prepare some data
x=[1,2,3,4,5]
y=[6,7,8,9,10]

#prepare the output file
output_file("Line.html")

#create a figure object
f=figure()

#create a line plot
f.line(x,y)

#write the plot in the figure object
show(f)

# %%
#writing a basic Bokeh line graph

#importing Bokeh
from bokeh.plotting import figure
from bokeh.io import output_file, show

#prepare some data
x=[1,2,3,4,5]
y=[6,7,8,9,10]

#prepare the output file
output_file("Line.html")

#create a figure object
f=figure()

#create a line plot
f.triangle(x,y)

#write the plot in the figure object
show(f)

# %%
#writing a basic Bokeh line graph

#importing Bokeh
from bokeh.plotting import figure
from bokeh.io import output_file, show

#prepare some data
x=[1,2,3,4,5]
y=[6,7,8,9,10]

#prepare the output file
output_file("Line.html")

#create a figure object
f=figure()

#create a line plot
f.circle(x,y)

#write the plot in the figure object
show(f)

# %%
#writing a basic Bokeh line graph

#importing Bokeh
from bokeh.plotting import figure
from bokeh.io import output_file, show
import pandas

#prepare some data
df=pandas.read_csv("data.csv")
x=df["x"]
y=df["y"]


#prepare the output file
output_file("Line_from_csv.html")

#create a figure object
f=figure()

#create a line plot
f.line(x,y)

#write the plot in the figure object
show(f)

# %%
#writing a Bokeh graph for percentage of women with bachelors degrees over time

#importing Bokeh
from bokeh.plotting import figure
from bokeh.io import output_file, show
import pandas

#prepare some data
df=pandas.read_csv("bachelors.csv")
x=df["Year"]
y=df["Engineering"]


#prepare the output file
output_file("Bachelors_bokeh.html")

#create a figure object
f=figure()
f.title.text="Women's bachelors degree over the years"
f.title.text_color="Red"
f.title.text_font="times"
f.title.text_font_style="bold"
f.xaxis.minor_tick_line_color="Red"
f.yaxis.minor_tick_line_color="Red"
f.xaxis.axis_label="Year"
f.yaxis.axis_label="Engineering"



#create a line plot
f.line(x,y)

#write the plot in the figure object
show(f)

# %%
#writing a Bokeh graph for percentage of women with bachelors degrees over time

#importing Bokeh
from bokeh.plotting import figure
from bokeh.io import output_file, show
import pandas

#prepare some data
df=pandas.read_excel("verlegenhuken.xlsx")
df["Temperature"] = df["Temperature"]/10
df["Pressure"] = df["Pressure"]/10


#prepare the output file
output_file("Weather.html")

#create a figure object
f=figure()
f.title.text="Temperature and Air Pressure"
f.title.text_color="Red"
f.title.text_font="times"
f.title.text_font_style="bold"
f.xaxis.minor_tick_line_color="Red"
f.yaxis.minor_tick_line_color="Red"
f.xaxis.axis_label="Temperature"
f.yaxis.axis_label="Pressure"



#create a line plot
f.circle(df["Temperature"],df["Pressure"], size=0.75)

#write the plot in the figure object
show(f)

# %%
#writing a Bokeh graph for percentage of women with bachelors degrees over time

#importing Bokeh
from bokeh.plotting import figure
from bokeh.io import output_file, show
import pandas

df=pandas.read_csv("http://www.google.com/finance/historical?q=NASDAQ:ADBE&startdate=Jan+01%2C+2009&enddate=Aug+2%2C+2012&output=csv")

p=figure(width=500,height=500,x_axis_type="datetime")

p.line(df["Date"],df["Close"], color="Orange", alpha=0.5)

output_file("Timeseries.html")
show(p)
